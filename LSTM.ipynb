# %%
import pandas as pd
import numpy as np

# Generate synthetic data
np.random.seed(42)
n_samples = 1000

data = {
    'barangay': np.random.choice(['Barangay 1', 'Barangay 2', 'Barangay 3'], n_samples),
    'incident_type': np.random.choice(['Theft', 'Assault', 'Vandalism'], n_samples),
    'date_committed': pd.date_range(start='2022-01-01', periods=n_samples, freq='D'),
    'time_committed': np.random.randint(0, 24, n_samples),
    'next_day_crime': np.random.choice([0, 1], n_samples)
}

df = pd.DataFrame(data)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Encoding categorical variables
le_barangay = LabelEncoder()
le_incident = LabelEncoder()
df['barangay'] = le_barangay.fit_transform(df['barangay'])
df['incident_type'] = le_incident.fit_transform(df['incident_type'])

# Creating time features
df['day_of_week'] = df['date_committed'].dt.dayofweek
df['month'] = df['date_committed'].dt.month

# Prepare input features and labels
features = df[['barangay', 'incident_type', 'time_committed', 'day_of_week', 'month']]
labels = df['next_day_crime']

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
import tensorflow as tf

# Reshape data for LSTM
X_train = np.array(X_train).reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = np.array(X_test).reshape((X_test.shape[0], 1, X_test.shape[1]))

# Build LSTM model
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5183 - loss: 0.6913 - val_accuracy: 0.5000 - val_loss: 0.6948
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5131 - loss: 0.6909 - val_accuracy: 0.5050 - val_loss: 0.6953
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5269 - loss: 0.6900 - val_accuracy: 0.5100 - val_loss: 0.6950
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5135 - loss: 0.6890 - val_accuracy: 0.4800 - val_loss: 0.6958
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5498 - loss: 0.6873 - val_accuracy: 0.5050 - val_loss: 0.6960
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5329 - loss: 0.6904 - val_accuracy: 0.5050 - val_loss: 0.6955
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5375 - loss: 0.6907 - val_accuracy: 0.4500 - val_loss: 0.6951
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5523 - loss: 0.6885 - val_accuracy: 0.5150 - val_loss: 0.6957
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5080 - loss: 0.6913 - val_accuracy: 0.4650 - val_loss: 0.6955
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5265 - loss: 0.6898 - val_accuracy: 0.4850 - val_loss: 0.6960
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5561 - loss: 0.6879 - val_accuracy: 0.4650 - val_loss: 0.6960
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5439 - loss: 0.6885 - val_accuracy: 0.4950 - val_loss: 0.6963
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5672 - loss: 0.6863 - val_accuracy: 0.4800 - val_loss: 0.6959
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5310 - loss: 0.6875 - val_accuracy: 0.4650 - val_loss: 0.6956
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5468 - loss: 0.6882 - val_accuracy: 0.4950 - val_loss: 0.6962
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5562 - loss: 0.6902 - val_accuracy: 0.4850 - val_loss: 0.6958
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5260 - loss: 0.6879 - val_accuracy: 0.4850 - val_loss: 0.6958
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5547 - loss: 0.6842 - val_accuracy: 0.4900 - val_loss: 0.6970
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5618 - loss: 0.6847 - val_accuracy: 0.4850 - val_loss: 0.6966
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5815 - loss: 0.6824 - val_accuracy: 0.4700 - val_loss: 0.6966
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5667 - loss: 0.6865 - val_accuracy: 0.4850 - val_loss: 0.6963
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5530 - loss: 0.6852 - val_accuracy: 0.5050 - val_loss: 0.6963
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5801 - loss: 0.6844 - val_accuracy: 0.4900 - val_loss: 0.6970
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5646 - loss: 0.6855 - val_accuracy: 0.4850 - val_loss: 0.6969
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5906 - loss: 0.6824 - val_accuracy: 0.5000 - val_loss: 0.6970
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5677 - loss: 0.6839 - val_accuracy: 0.5200 - val_loss: 0.6971
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5473 - loss: 0.6865 - val_accuracy: 0.4850 - val_loss: 0.6972
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5611 - loss: 0.6839 - val_accuracy: 0.4850 - val_loss: 0.6975
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5904 - loss: 0.6734 - val_accuracy: 0.4800 - val_loss: 0.7090
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5732 - loss: 0.6727 - val_accuracy: 0.5150 - val_loss: 0.7122
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5478 - loss: 0.6769 - val_accuracy: 0.4950 - val_loss: 0.7100
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5729 - loss: 0.6721 - val_accuracy: 0.4700 - val_loss: 0.7102
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5766 - loss: 0.6721 - val_accuracy: 0.5050 - val_loss: 0.7114
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5971 - loss: 0.6657 - val_accuracy: 0.5050 - val_loss: 0.7111
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5953 - loss: 0.6690 - val_accuracy: 0.5000 - val_loss: 0.7114
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5667 - loss: 0.6773 - val_accuracy: 0.5050 - val_loss: 0.7122
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6000 - loss: 0.6682 - val_accuracy: 0.5050 - val_loss: 0.7132
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5706 - loss: 0.6716 - val_accuracy: 0.4850 - val_loss: 0.7125
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5449 - loss: 0.6770 - val_accuracy: 0.4750 - val_loss: 0.7126
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5679 - loss: 0.6705 - val_accuracy: 0.4950 - val_loss: 0.7129
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6158 - loss: 0.6669 - val_accuracy: 0.4850 - val_loss: 0.7136
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6044 - loss: 0.6719 - val_accuracy: 0.4950 - val_loss: 0.7148
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5726 - loss: 0.6729 - val_accuracy: 0.4850 - val_loss: 0.7135
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5425 - loss: 0.6779 - val_accuracy: 0.5000 - val_loss: 0.7149
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5998 - loss: 0.6704 - val_accuracy: 0.4900 - val_loss: 0.7150
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5616 - loss: 0.6720 - val_accuracy: 0.4950 - val_loss: 0.7158
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5955 - loss: 0.6617 - val_accuracy: 0.4750 - val_loss: 0.7157
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5989 - loss: 0.6655 - val_accuracy: 0.4750 - val_loss: 0.7148
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6069 - loss: 0.6576 - val_accuracy: 0.4750 - val_loss: 0.7162
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6057 - loss: 0.6687 - val_accuracy: 0.4900 - val_loss: 0.7152
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5998 - loss: 0.6595 - val_accuracy: 0.4700 - val_loss: 0.7176
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5711 - loss: 0.6716 - val_accuracy: 0.5000 - val_loss: 0.7172
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6039 - loss: 0.6682 - val_accuracy: 0.4800 - val_loss: 0.7164
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5864 - loss: 0.6672 - val_accuracy: 0.4900 - val_loss: 0.7174
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5857 - loss: 0.6692 - val_accuracy: 0.4850 - val_loss: 0.7189
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5738 - loss: 0.6704 - val_accuracy: 0.4750 - val_loss: 0.7186
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5779 - loss: 0.6698 - val_accuracy: 0.4800 - val_loss: 0.7173
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5876 - loss: 0.6657 - val_accuracy: 0.4750 - val_loss: 0.7182
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4682 - loss: 0.7270
# Test Accuracy: 0.4749999940395355

# %%
# Make predictions on the test set
predictions = model.predict(X_test)

# Convert predictions to probabilities
predicted_probabilities = predictions.flatten()  # Flatten to 1D array

# Display the predicted probabilities alongside the actual labels
results = pd.DataFrame({'Actual': y_test, 'Predicted Probability': predicted_probabilities})
print(results.head(10))

# Optional: Thresholding to classify the probabilities
threshold = 0.5
results['Predicted Class'] = (results['Predicted Probability'] >= threshold).astype(int)

# Evaluate performance
from sklearn.metrics import classification_report

print(classification_report(results['Actual'], results['Predicted Class']))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
#      Actual  Predicted Probability
# 521       0               0.481363
# 737       0               0.444919
# 740       0               0.457086
# 660       0               0.489979
# 411       0               0.490337
# 678       0               0.479848
# 626       1               0.488582
# 513       0               0.488192
# 859       1               0.483590
# 136       0               0.501042
#               precision    recall  f1-score   support
#
#            0       0.48      0.72      0.57        99
#            1       0.46      0.24      0.31       101
#
#     accuracy                           0.47       200
#    macro avg       0.47      0.48      0.44       200
# weighted avg       0.47      0.47      0.44       200
